// %% [markdown]
// # Making a shape

// %%
#include <iostream>

using namespace std;

int main(){
    cout << "   /|" <<endl;
    cout << "  / |" <<endl;
    cout << " /  |" <<endl;
    cout << "/___|" <<endl;
    return 0;
}
// Out:
// input_line_8:3:11: error: function definition is not allowed here
// int main(){
//           ^
// Interpreter Error:

// %%
   /|
  / |
 /  |
/___|

// %% [markdown]
// # CharacterAge

// %%
#include <iostream>

using namespace std;

int main()
{
    string characterName = "John";
    int characterAge;
    characterAge = 35;

    characterAge = 35; //numbers don't need quotes
    cout << "There once was a man named " << characterName<<" ." <<endl;
    cout << "He is " << characterAge <<" years old." <<endl;
    cout << "He did not like the name "<< characterName<<" ." <<endl;
    cout << "He did not like being "<<characterAge<< " years old." <<endl;
    
    return 0;
}

// %%
[Running] cd "c:\Users\patku_kjg5mjl\Desktop\C++\Practicemyself\" && g++ Practice1.cpp -o Practice1 && "c:\Users\patku_kjg5mjl\Desktop\C++\Practicemyself\"Practice1
There once was a man named John .
He is 35 years old.
He did not like the name John .
He did not like being 35 years old.

// %%
#include <iostream>

using namespace std;

int main()
{
    string characterName = "John";
    int characterAge;
    characterAge = 35;

    characterAge = 35; //numbers don't need quotes
    cout << "There once was a man named " << characterName<<" ." <<endl;
    cout << "He is " << characterAge <<" years old." <<endl;
    
    characterName = "Alise"; //change variable here
    cout << "He did not like the name "<< characterName<<" ." <<endl;
    cout << "He did not like being "<<characterAge<< " years old." <<endl;
    
    return 0;
}

// %%
There once was a man named John .
He is 35 years old.
He did not like the name Alise .
He did not like being 35 years old.

// %% [markdown]
// # Length

// %%
#include <iostream>

using namespace std;

int main()
{
    string phrase = "Patrica";
    cout << phrase.length();

    return 0;
}

// %% [markdown]
// # Placement

// %%
#include <iostream>

using namespace std;

int main()
{
    string phrase = "Patrica";
    cout << phrase[3];

    return 0;
}

// %% [markdown]
// # Change word

// %%
#include <iostream>
using namespace std;

int main()
{
    string phrase = "Patrica";
    phrase[0] = 'b';
    cout << phrase;

    return 0;
}

// %%
batrica

// %% [markdown]
// # Homework

// %% [markdown]
// ### 1) only run out 0 stack

// %%
#include <iostream>
#include <string>
using namespace std;

int main()
{
    string choice;

  //  木材 = "0";
  //  竹子 = "|";
  //  鷹架 = "H";

    cout << "請指定一種材料,我將用這種材料為你蓋出一座金字塔" << endl;
    cout << "0:木材 |:竹子 H:鷹架 " << endl;
    cout << "你的選擇是: ";
    cin >> choice;

    cout <<"  0 "<<endl;
    cout <<" 000 "<<endl;
    cout <<"00000 "<<endl;

    return 0;
}
