// %%
#include <iostream>    //Library-contains definitions to objects like cin, cout, cerr etc.
using namespace std; // standard or else have to include std:: before every line
int main(){   //int integer  //main function
    cout << "Hello, world!\n"; //cout- output // << info direction

    return 0;
}
// Out:
// input_line_12:3:12: error: function definition is not allowed here
// int main() {
//            ^
// Interpreter Error:

// %% [markdown]
// # Comment

// %%
/*
shift-control c
shift-control x*/

/*
// Out:
// input_line_13:4:1: error: unterminated /* comment
// /*
// ^
// Interpreter Error:

// %%
{
    tab after {}
}
