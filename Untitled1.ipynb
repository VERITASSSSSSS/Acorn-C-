// %%
#include<iostream>
#include<cmath>
using namespace std;

int main() 
{
    float h, w;
    cout<<"Please input your height(meter): ";
    cin>> h;
    cout<<"Please input your weight(kilogram): ";
    cin>>w;
    cout<<"Your BMI is " <<  w/pow(h,2)<<'\n';
}

// %%
/* Camel */
snake_case
camelCase

// %% [markdown]
// # Class

// %%
a = b == c

== RELATIONAL OPERATORS comparing right side with left side, returns true/false
=  ASSIGNMENT OPERATORS

// %%
if (BMI < 45)
{
    cout>>"Eat less">>endl;
}

// %%
if(number%2==0) //Modulus Operator (%): remainder
{
    
}

// %%
蝶摩根定律
#include namespace cv;
Mat img = imread("https://www.onlinemathlearning.com/image-files/de-morgans-law.png");
imshow("My image", img)

// %%
#include<iostream>
using namespace std;

int main(){
    cout<<!(0&&0)<<' '<<(!0)||(!0)<<'\n'; //and
    cout<<!(0&&1)<<' '<<(!0)||(!1)<<'\n';
}

//!(a>b) //a不大於b

// %%
if(0)
{
    cout<<"true"<<'\n';
}

// %% [markdown]
// # Switch Case

// %%
switch(n)
{
    case 0:
        /*code*/
        break;
        
    case 1:
        /*code*/
        break;
        
    default:
        /*code*/
        break;
}

// %%
// If else

#include <iostream>
using namespace std;

int main()
{
    char n;
    if (n==1)
    {
        cout<<"陸月"<<endl;
    }

    if (n==5)
    {
        cout<<"木月"<<endl;
    }
    
    if (n==10)
    {
        cout<<"神無月"<<endl;
    }
}

// %%
//Switch cases

int main()
{
    switch(n)
    {
    case 1:
        cout<<"陸月"<<endl;
        break;
    
    case 5:
        cout<<"皋月"<<endl;
        break;
    
    case 10:
        cout<<"神無月"<<endl;
        break;
    }
    
}

// %%
int x;
cin>>x;
(x%2==0)?cout<<"even\n":cout<<"odd\n";

// %% [markdown]
// # 三次元

// %%
int x = (n! = 0)?1:0;
cout<<(a%2 ==0? "Even":"Odd")<<endl;
